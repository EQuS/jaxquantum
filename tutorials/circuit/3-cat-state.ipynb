# %%
# %load_ext autoreload
# %autoreload 2

# %%
import jaxquantum as jqt
import jaxquantum.circuits as jqtc
from jax import jit, grad
import jax.numpy as jnp
from math import prod
import matplotlib.pyplot as plt

import jax
import optax
import functools

# %%
def prep_state(beta):
    N = 20
    reg = jqtc.Register([2,N])
    cirq = jqtc.Circuit.create(reg, layers=[])

    # Pi/2 Pulse
    cirq.append(jqtc.H(), 0)

    # CD
    cirq.append(jqtc.CD(N, beta),[0,1])

    # Measure 
    cirq.append(MX_plus(), 0)

    initial_state = jqt.ket2dm(jqt.basis(2,0) ^ jqt.basis(N,0))
    res = jqtc.simulate(cirq, initial_state, mode="kraus")

    return res[-1][-1].unit()

def state_fid(beta):
    N = 20
    cat_state = (jqt.coherent(N,-beta/2) + jqt.coherent(N,beta/2)).unit()
    prepared_state = jqt.ptrace(prep_state(beta),1)
    return jqt.overlap(cat_state, prepared_state)

# %%
state_fid(2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 state_fid(2)
#
# Cell In[3], line 23, in state_fid(beta)
#      21 N = 20
#      22 cat_state = (jqt.coherent(N,-beta/2) + jqt.coherent(N,beta/2)).unit()
# ---> 23 prepared_state = jqt.ptrace(prep_state(beta),1)
#      24 return jqt.overlap(cat_state, prepared_state)
#
# Cell In[3], line 10, in prep_state(beta)
#       7 cirq.append(jqtc.H(), 0)
#       9 # CD
# ---> 10 cirq.append(jqtc.CD(N, beta),[0,1])
#      12 # Measure
#      13 cirq.append(MX_plus(), 0)
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/circuits/library/oscillator.py:22, in CD(N, beta)
#      19 gg = g @ g.dag()
#      20 ee = e @ e.dag()
# ---> 22 return Gate.create(
#      23     [2,N],
#      24     name="CD",
#      25     params={"beta": beta},
#      26     gen_U = lambda params: (gg ^ displace(N, params["beta"]/2)) + (ee ^ displace(N, -params["beta"]/2)),
#      27     num_modes=2
#      28 )
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/circuits/gates.py:72, in Gate.create(cls, dims, name, params, ts, gen_U, gen_H, gen_KM, num_modes)
#      70     _KM = gen_KM(params)
#      71 elif _U is not None:
# ---> 72     _KM = Qarray.from_list([_U])
#      74 return Gate(
#      75     dims = dims,
#      76     _U = _U,
#    (...)
#      82     num_modes = num_modes
#      83 )
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/core/qarray.py:110, in Qarray.from_list(cls, qarr_list)
#     108 bdims = (len(qarr_list),)
#     109 data = jnp.array([qarr.data for qarr in qarr_list])
# --> 110 return cls.create(data, dims=qarr_list[0].dims, bdims=bdims)
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/core/qarray.py:88, in Qarray.create(cls, data, dims, bdims)
#      85 if dims is None:
#      86     dims = ((data.shape[-2],), (data.shape[-1],))
# ---> 88 check_dims(dims, bdims, data.shape)
#      90 qdims = Qdims(dims)
#      92 # NOTE: Constantly tidying up on Qarray creation might be a bit overkill.
#      93 # It increases the compilation time, but only very slightly
#      94 # increased the runtime of the jit compiled function.
#      95 # We could instead use this tidy_up where we think we need it.
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/core/dims.py:27, in check_dims(dims, bdims, data_shape)
#      26 def check_dims(dims: Tuple[Tuple[int]], bdims: Tuple[int], data_shape: Array) -> bool:
# ---> 27     assert bdims == data_shape[:-2], "Data shape should be consistent with dimensions."
#      28     assert data_shape[-2] == prod(dims[0]), "Data shape should be consistent with dimensions."
#      29     assert data_shape[-1] == prod(dims[1]), "Data shape should be consistent with dimensions."
#
# AssertionError: Data shape should be consistent with dimensions.

# %%
# start with a dm instead

N = 20
beta = 4
state = (jqt.coherent(N,-beta/2) + jqt.coherent(N,beta/2)).unit()
pts = jnp.linspace(-4,4, 101)
ax = jqt.plot_wigner(state, pts)
ax.set_xlabel("Re[α]")
ax.set_ylabel("Im[α]")


state = prep_state(4)
pts = jnp.linspace(-4,4, 101)
ax = jqt.plot_wigner(jqt.ptrace(state,1), pts)
ax.set_xlabel("Re[α]")
ax.set_ylabel("Im[α]")
# Out:
# Text(0, 0.5, 'Im[α]')
