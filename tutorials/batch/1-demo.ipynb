# %%
# %load_ext autoreload
# %autoreload 2

# %%
from jax import jit
import jaxquantum as jqt
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
omega_q = 5.0 #GHzz
Omega = jnp.array([.1, .2, .3])
g_state = jqt.basis(2,0) ^ jqt.basis(2,0)
g_state_dm = g_state.to_dm()

ts = jnp.linspace(0,5*jnp.pi/Omega[0],101)
c_ops = jqt.Qarray.from_list([0.1*jqt.sigmam()^jqt.identity(N=2), 0.2*jqt.sigmam()^jqt.identity(N=2)])

sz0 = jqt.sigmaz() ^ jqt.identity(N=2)

@jit
def Ht(t):
    H0 = omega_q/2.0*((jqt.sigmaz()^jqt.identity(N=2)) + (jqt.identity(N=2)^jqt.sigmaz()))
    H1 = Omega*jnp.cos((omega_q)*t)*((jqt.sigmax()^jqt.identity(N=2)) + (jqt.identity(N=2)^jqt.sigmax()))
    return H0 + H1

solver_options = jqt.SolverOptions.create(progress_meter=True)

# %%
g_state_dm = jqt.Qarray.from_list([g_state_dm, g_state_dm, g_state_dm])

# %%
states = jqt.mesolve(
    Ht, g_state_dm, ts, c_ops=c_ops, solver_options=solver_options
)
# Out:
# 100% |██████████| [00:00<00:00, 561.99%/s]

# %%
szt = jnp.real(jqt.overlap(sz0, states))

# %%
fig, ax = plt.subplots(1, dpi=200, figsize=(4,3))
ax.plot(ts, szt[:,0], "-")
ax.plot(ts, szt[:,1], "--")
ax.plot(ts, szt[:,2], "--")
ax.set_xlabel("Time (ns)")
ax.set_ylabel("<σz(t)>")
fig.tight_layout()

# %%
omega_qs = jnp.array([4,5,6.0]) #GHzz
Omega = .1
g_state = jqt.basis(2,0) ^ jqt.basis(2,0)
g_state_dm = g_state.to_dm()

ts = jnp.linspace(0,5*jnp.pi/Omega,101)
c_ops = [0.1*jqt.sigmam()^jqt.identity(N=2)]

sz0 = jqt.sigmaz() ^ jqt.identity(N=2)

@jit
def Ht(t):
    H0 = omega_qs/2.0*((jqt.sigmaz()^jqt.identity(N=2)) + (jqt.identity(N=2)^jqt.sigmaz()))
    H1 = Omega*jnp.cos((omega_qs)*t)*((jqt.sigmax()^jqt.identity(N=2)) + (jqt.identity(N=2)^jqt.sigmax()))
    return H0 + H1

# solver_options = jqt.SolverOptions.create(progress_meter=True)
# states = jqt.mesolve(g_state_dm, ts, c_ops=c_ops, Ht=Ht, solver_options=solver_options) 
# szt = jnp.real(jqt.calc_expect(sz0, states))


# fig, ax = plt.subplots(1, dpi=200, figsize=(4,3))
# ax.plot(ts, szt)
# ax.set_xlabel("Time (ns)")
# ax.set_ylabel("<σz(t)>")
# fig.tight_layout()

# %%
solver_options = jqt.SolverOptions.create(progress_meter=True)
states = jqt.mesolve(g_state_dm, ts, c_ops=c_ops, Ht=Ht, solver_options=solver_options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 solver_options = jqt.SolverOptions.create(progress_meter=True)
# ----> 2 states = jqt.mesolve(g_state_dm, ts, c_ops=c_ops, Ht=Ht, solver_options=solver_options)
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/core/solvers.py:166, in mesolve(ρ0, t_list, c_ops, H0, Ht, solver_options)
#     163 H0 = jnp.asarray(H0.data) if H0 is not None else None
#     164 Ht_data = lambda t: Ht(t).data if Ht is not None else None
# --> 166 ys = mesolve_data(ρ0, t_list, c_ops, H0, Ht_data, solver_options)
#     168 return jnps2jqts(ys, dims=dims)
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/core/solvers.py:227, in mesolve_data(ρ0, t_list, c_ops, H0, Ht, solver_options)
#     222         rho_dot += spre(op)(rho)
#     224     return rho_dot
# --> 227 sol = solve(ρ0, f, t_list, [H0, c_ops], solver_options=solver_options)
#     229 return sol.ys
#
# File ~/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/core/solvers.py:113, in solve(ρ0, f, t_list, args, solver_options)
#     111 with warnings.catch_warnings():
#     112     warnings.simplefilter('ignore', UserWarning) # NOTE: suppresses complex dtype warning in diffrax
# --> 113     sol = diffeqsolve(
#     114         term,
#     115         solver,
#     116         t0=t_list[0],
#     117         t1=t_list[-1],
#     118         dt0=t_list[1] - t_list[0],
#     119         y0=ρ0,
#     120         saveat=saveat,
#     121         stepsize_controller=stepsize_controller,
#     122         args=args,
#     123         max_steps=solver_options.max_steps,
#     124         progress_meter=CustomProgressMeter() if solver_options.progress_meter else NoProgressMeter(),
#     125     )
#     127 return sol
#
#     [... skipping hidden 15 frame]
#
# File /opt/miniconda3/envs/jax-framework/lib/python3.9/site-packages/diffrax/_integrate.py:781, in diffeqsolve(terms, solver, t0, t1, dt0, y0, args, saveat, stepsize_controller, adjoint, discrete_terminating_event, max_steps, throw, progress_meter, solver_state, controller_state, made_jump)
#     777 # Error checking
#     778 if not _term_compatible(
#     779     y0, args, terms, solver.term_structure, solver.term_compatible_contr_kwargs
#     780 ):
# --> 781     raise ValueError(
#     782         "`terms` must be a PyTree of `AbstractTerms` (such as `ODETerm`), with "
#     783         f"structure {solver.term_structure}"
#     784     )
#     786 if is_sde(terms):
#     787     if not isinstance(solver, (AbstractItoSolver, AbstractStratonovichSolver)):
#
# ValueError: `terms` must be a PyTree of `AbstractTerms` (such as `ODETerm`), with structure <class 'diffrax._term.AbstractTerm'>

# %%
Ht(0.0)
# Out:
# Quantum array: dims = ((2, 2), (2, 2)), bdims = (3,), shape = (3, 4, 4), type = oper
# Qarray data =
# [[[ 4. +0.j  0.1+0.j  0.1+0.j  0. +0.j]
#   [ 0.1+0.j  0. +0.j  0. +0.j  0.1+0.j]
#   [ 0.1+0.j  0. +0.j  0. +0.j  0.1+0.j]
#   [ 0. +0.j  0.1+0.j  0.1+0.j -4. +0.j]]
#
#  [[ 5. +0.j  0.1+0.j  0.1+0.j  0. +0.j]
#   [ 0.1+0.j  0. +0.j  0. +0.j  0.1+0.j]
#   [ 0.1+0.j  0. +0.j  0. +0.j  0.1+0.j]
#   [ 0. +0.j  0.1+0.j  0.1+0.j -5. +0.j]]
#
#  [[ 6. +0.j  0.1+0.j  0.1+0.j  0. +0.j]
#   [ 0.1+0.j  0. +0.j  0. +0.j  0.1+0.j]
#   [ 0.1+0.j  0. +0.j  0. +0.j  0.1+0.j]
#   [ 0. +0.j  0.1+0.j  0.1+0.j -6. +0.j]]]
