# %%
# %load_ext autoreload
# %autoreload 2

# %%
from jaxquantum.codes import BinomialQubit #, BosonicRegister, BosonicCircuit, execute
from jaxquantum import plot_wigner
import jaxquantum as jqt

# %%
qubit = BinomialQubit(params={"N":50}, name="")
# breg = BosonicRegister([qubit])
# bcirc = BosonicCircuit(breg)
qubit.plot_code_states()
# Out:
# /Users/phionx/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/codes/base.py:294: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
qubit.plot_code_states(qp_type="qfunc")

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
# %timeit results = execute(bcirc, "unitary_jax")
# Out:
# 10.2 µs ± 164 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
results = execute(bcirc, "unitary_jax")
results.plot(bcirc,0)
