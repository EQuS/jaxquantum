# %%
# %load_ext autoreload
# %autoreload 2

# %%
from jaxquantum.codes import Qubit #, BosonicRegister, BosonicCircuit, execute

# %% [markdown]
# # Fock Qubit

# %%
qubit = Qubit()
# breg = BosonicRegister([qubit])
# bcirc = BosonicCircuit(breg)
qubit.plot_code_states()
# Out:
# /Users/phionx/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/codes/base.py:294: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
qubit.plot_code_states(qp_type="qfunc")

# %% [markdown]
# # Circuit

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
results = execute(bcirc, "unitary_jax")
results.plot(bcirc,0)

# %% [markdown]
# # MultiQubit

# %%
qubit1 = Qubit()
qubit2 = Qubit()
breg2 = BosonicRegister([qubit1,qubit2])
bcirc2 = BosonicCircuit(breg2)

bcirc2.plot()

# set up circuit
bcirc2.reset()
bcirc2.x(1)

# %%
results2 = execute(bcirc2, "unitary_jax")
results2.plot(bcirc2)
