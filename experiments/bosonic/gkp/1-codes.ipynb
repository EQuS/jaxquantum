# %%
# %load_ext autoreload
# %autoreload 2

# %%
from jaxquantum.codes import GKPQubit,  HexagonalGKPQubit, SquareGKPQubit, RectangularGKPQubit#, BosonicRegister, BosonicCircuit, execute

# %% [markdown]
# # Square GKP Qubit

# %%
qubit = SquareGKPQubit(params={"N":200}) # GKPQubit == SquareGKPQubit
# breg = BosonicRegister([qubit])
# bcirc = BosonicCircuit(breg)
qubit.plot_code_states()
# Out:
# /Users/phionx/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/codes/base.py:301: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
qubit.plot_code_states(qp_type="husimi")
# Out:
# /Users/phionx/Github/qc/EQuS/bosonic/jax/jaxquantum/jaxquantum/codes/base.py:294: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
results = execute(bcirc, "unitary_jax")
results.plot(bcirc,0)

# %% [markdown]
# # Rectangular GKP Qubit

# %%
qubit = RectangularGKPQubit(params={"N":200, "delta": 0.25}, name="")
breg = BosonicRegister([qubit])
bcirc = BosonicCircuit(breg)
qubit.plot_code_states()
# Out:
# /Users/phionx/Github/qc/EQuS/bosonic/jax/bosonic/bosonic/codes/base.py:282: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
qubit = RectangularGKPQubit(params={"N":200})
breg = BosonicRegister([qubit])
bcirc = BosonicCircuit(breg)
qubit.plot_code_states()

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
results = execute(bcirc, "unitary_jax")
results.plot(bcirc,0)

# %% [markdown]
# # Hexagonal GKP Qubit

# %%
qubit = HexagonalGKPQubit(params={"N":200})
breg = BosonicRegister([qubit])
bcirc = BosonicCircuit(breg)
qubit.plot_code_states()
# Out:
# /Users/phionx/Github/qc/EQuS/bosonic/jax/bosonic/bosonic/codes/base.py:282: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
# %timeit results = execute(bcirc, "unitary_jax")
# Out:
# 3.61 µs ± 45.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
results.plot(bcirc,0)
